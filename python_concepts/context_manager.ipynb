# %% [markdown]
# What is a Context Manager?
#
# A context manager is an object that automatically acquires and releases resources

# %% [markdown]
# with out contetx managers
#
# file = open("data.txt","r")
#
# data = file.read()
#
# file.close()

# %% [markdown]
# with context manager
#
# with open("data.txt",r) as file:
#     data = file.read()
