# %% [markdown]
# Pattern	Where You'll See It
# Singleton	Database connections, configuration managers, model loaders
# Factory	Creating LLMs, embedding models, vector stores
# Builder	LLM deployment configs, request objects, cloud resources
# Strategy	Model selection, payment methods, ranking algorithms
# Observer	Event-driven systems, notifications, monitoring
# Adapter	Integrating OpenAI, Anthropic, Ollama, vLLM behind one interface
# Decorator	Python @decorator, logging, authentication, caching
# Facade	Simplifying complex APIs (e.g., RAG pipeline wrapper)
# Proxy	Lazy loading models, caching, access control
# State	Order processing, chatbot conversation flow, workflow engines
